# %%
import numpy as np
import pandas as pd
import seaborn as sns
from matplotlib import pyplot as plt

# %%
#import Data sets 
ABBV = pd.read_csv('ABBV.csv') # Abbvie
LLY = pd.read_csv('LLY.csv') # Eli Lilly 
PFE = pd.read_csv('PFE.csv') # Pfizer
JNJ = pd.read_csv('JNJ.csv') # Johnson & Johnson 
MRK = pd.read_csv('MRK.csv') # Merek

# %%
ABBV.head(10)
# Out:
#          Date        Low       Open    Volume       High      Close  \
# 0  02-01-2013  34.099998  34.919998  13767900  35.400002  35.119999
# 1  03-01-2013  34.160000  35.000000  16739300  35.000000  34.830002
# 2  04-01-2013  34.250000  34.619999  21372100  34.889999  34.389999
# 3  07-01-2013  34.150002  34.150002  17897100  35.450001  34.459999
# 4  08-01-2013  33.360001  34.290001  17863300  34.639999  33.709999
# 5  09-01-2013  33.610001  33.610001  18800400  33.950001  33.900002
# 6  10-01-2013  33.330002  33.660000  15658100  34.000000  34.000000
# 7  11-01-2013  33.349998  33.590000  11191500  33.900002  33.849998
# 8  14-01-2013  33.799999  34.009998  11584900  34.250000  34.090000
# 9  15-01-2013  33.709999  33.709999  13040200  34.720001  34.599998
#
#    Adjusted Close
# 0       23.985445
# 1       23.787374
# 2       23.486879
# 3       23.534689
# 4       23.022474
# 5       23.152235
# 6       23.220530
# 7       23.393293
# 8       23.559164
# 9       23.911606

# %%
JNJ.head(10)
# Out:
#          Date       Low      Open   Volume      High     Close  Adjusted Close
# 0  02-01-1970  1.218750  1.250000  1195200  1.253472  1.218750        0.402553
# 1  05-01-1970  1.187500  1.218750   964800  1.222222  1.189236        0.392805
# 2  06-01-1970  1.184028  1.189236  1036800  1.211806  1.211806        0.400260
# 3  07-01-1970  1.203125  1.211806   331200  1.215278  1.206597        0.398539
# 4  08-01-1970  1.206597  1.206597   460800  1.225694  1.215278        0.401407
# 5  09-01-1970  1.222222  1.222222   748800  1.239583  1.222222        0.403701
# 6  12-01-1970  1.201389  1.222222   864000  1.222222  1.201389        0.396819
# 7  13-01-1970  1.204861  1.204861   849600  1.222222  1.211806        0.400260
# 8  14-01-1970  1.211806  1.211806   619200  1.232639  1.229167        0.405994
# 9  15-01-1970  1.227431  1.229167  1209600  1.232639  1.230903        0.406567

# %%
PFE.head(10)
# Out:
#          Date       Low      Open   Volume      High     Close  Adjusted Close
# 0  01-06-1972  0.802993  0.000000  2458771  0.815346  0.815346        0.176882
# 1  02-06-1972  0.802993  0.815346  1613885  0.817817  0.805463        0.174738
# 2  05-06-1972  0.798051  0.805463  2585251  0.807934  0.802993        0.174202
# 3  06-06-1972  0.800522  0.802993  2347469  0.825229  0.820288        0.177954
# 4  07-06-1972  0.807934  0.820288  1032077  0.820288  0.820288        0.177954
# 5  08-06-1972  0.815346  0.820288  1067491  0.822759  0.815346        0.176882
# 6  09-06-1972  0.815346  0.815346  1563293  0.822759  0.820288        0.177954
# 7  12-06-1972  0.820288  0.820288  1942733  0.835112  0.822759        0.178490
# 8  13-06-1972  0.817817  0.822759  2175456  0.835112  0.830171        0.180098
# 9  14-06-1972  0.825229  0.830171  2069213  0.835112  0.830171        0.180098

# %%
LLY.head(10)
# Out:
#          Date       Low      Open  Volume      High     Close  Adjusted Close
# 0  01-06-1972  4.023438  0.000000  456000  4.070313  4.046875        0.923313
# 1  02-06-1972  4.054688  4.054688  640000  4.093750  4.093750        0.934008
# 2  05-06-1972  4.023438  4.085938  464000  4.085938  4.039063        0.921530
# 3  06-06-1972  4.000000  4.039063  796800  4.039063  4.000000        0.912618
# 4  07-06-1972  3.992188  4.000000  584000  4.054688  4.046875        0.923313
# 5  08-06-1972  3.992188  4.046875  726400  4.062500  4.000000        0.912618
# 6  09-06-1972  4.007813  4.007813  296000  4.054688  4.046875        0.923313
# 7  12-06-1972  4.015625  4.046875  473600  4.078125  4.039063        0.921530
# 8  13-06-1972  4.046875  4.046875  478400  4.093750  4.078125        0.930443
# 9  14-06-1972  4.093750  4.093750  795200  4.179688  4.164063        0.950050

# %%
MRK.head(10)
# Out:
#          Date       Low      Open   Volume      High     Close  Adjusted Close
# 0  02-01-1970  1.471056  1.494248   498010  1.494248  1.474369        0.319674
# 1  05-01-1970  1.461116  1.474369   701741  1.484309  1.466086        0.317878
# 2  06-01-1970  1.457803  1.466086   596102  1.477682  1.477682        0.320392
# 3  07-01-1970  1.461116  1.477682   935654  1.490935  1.464430        0.317519
# 4  08-01-1970  1.467743  1.467743   520646  1.484309  1.474369        0.319674
# 5  09-01-1970  1.457803  1.474369  1712851  1.487622  1.471056        0.318955
# 6  12-01-1970  1.464430  1.471056   679104  1.479339  1.471056        0.318955
# 7  13-01-1970  1.451177  1.471056  1214842  1.474369  1.467743        0.318237
# 8  14-01-1970  1.447864  1.464430   550829  1.464430  1.464430        0.317519
# 9  15-01-1970  1.451177  1.464430  1109203  1.477682  1.457803        0.316082

# %%
JNJ.dtypes
# Out:
# Date               object
# Low               float64
# Open              float64
# Volume              int64
# High              float64
# Close             float64
# Adjusted Close    float64
# dtype: object

# %%
JNJ.isna().sum()
# Out:
# Date              0
# Low               0
# Open              0
# Volume            0
# High              0
# Close             0
# Adjusted Close    0
# dtype: int64

# %%
PFE.isna().sum()
# Out:
# Date              0
# Low               0
# Open              0
# Volume            0
# High              0
# Close             0
# Adjusted Close    0
# dtype: int64

# %%
LLY.isna().sum()
# Out:
# Date              0
# Low               0
# Open              0
# Volume            0
# High              0
# Close             0
# Adjusted Close    0
# dtype: int64

# %%
MRK.isna().sum()
# Out:
# Date              0
# Low               0
# Open              0
# Volume            0
# High              0
# Close             0
# Adjusted Close    0
# dtype: int64

# %%
JNJ_DtAftr = JNJ[JNJ['Date'] == '30-12-2021']# were We stop looking 
JNJ_DtAftr.head()
# Out:
#              Date     Low        Open   Volume        High       Close  \
# 13116  30-12-2021  171.75  172.119995  4231800  172.880005  172.309998
#
#        Adjusted Close
# 13116      172.309998

# %%
JNJ_DtBfr = JNJ[JNJ['Date'] == '02-01-2018'] # were we start looking
JNJ_DtBfr.head()
# Out:
#              Date         Low        Open   Volume        High       Close  \
# 12110  02-01-2018  138.720001  139.660004  6842100  139.949997  139.229996
#
#        Adjusted Close
# 12110      125.192604

# %%
import datetime
JNJ['month'] = pd.DatetimeIndex(JNJ['Date']).day
JNJ.head()
JNJ['year'] = pd.DatetimeIndex(JNJ['Date']).year

# %%
JNJ_Covid = JNJ.iloc[12110:13116]
JNJ_Covid.shape
# Out:
# (1006, 9)

# %%
date_list = JNJ['Date'].iloc[12110:13116:60]

# %%
f = plt.figure()
f.set_figwidth(24)
f.set_figheight(10)
plt.plot(JNJ_Covid['Date'], JNJ_Covid['Close'], Color = "green")

plt.xlabel('Date')
plt.ylabel('Closing Price')
plt.title('JNJ Stock Price' , fontsize = 25)
plt.grid()
plt.xticks(date_list, date_list)

plt.show()
# Out:
# C:\Users\noaht\AppData\Local\Temp/ipykernel_22292/3616410429.py:4: MatplotlibDeprecationWarning: Case-insensitive properties were deprecated in 3.3 and support will be removed two minor releases later
#   plt.plot(JNJ_Covid['Date'], JNJ_Covid['Close'], Color = "green")

# %%
PFE_DtAftr = PFE[PFE['Date'] == '30-12-2021']# were We stop looking 
PFE_DtAftr.head()
# Out:
#              Date        Low   Open    Volume       High      Close  \
# 12504  30-12-2021  57.529999  57.75  24559000  58.740002  58.400002
#
#        Adjusted Close
# 12504       58.400002

# %%
PFE_DtBfr = PFE[PFE['Date'] == '02-01-2018'] # were we start looking
PFE_DtBfr.head()
# Out:
#              Date        Low       Open    Volume       High      Close  \
# 11498  02-01-2018  34.383301  34.516129  17059833  34.648956  34.573055
#
#        Adjusted Close
# 11498       29.725769

# %%
PFE_Covid = PFE.iloc[11498:12504]
dates_PFE= PFE['Date'].iloc[11498:12504:60]

# %%
f = plt.figure()
f.set_figwidth(24)
f.set_figheight(10)
plt.plot(PFE_Covid['Date'], PFE_Covid['Close'], Color = "green")

plt.xlabel('Date')
plt.ylabel('Closing Price')
plt.title('PFE stock Price', fontsize = 25)
plt.grid()
plt.xticks(dates_PFE, dates_PFE)
plt.show()
# Out:
# C:\Users\noaht\AppData\Local\Temp/ipykernel_22292/2515178525.py:4: MatplotlibDeprecationWarning: Case-insensitive properties were deprecated in 3.3 and support will be removed two minor releases later
#   plt.plot(PFE_Covid['Date'], PFE_Covid['Close'], Color = "green")

# %%
ABBV_DtAftr = ABBV[ABBV['Date'] == '30-12-2021']# were We stop looking 
ABBV_DtAftr.head()
# Out:
#             Date         Low    Open   Volume        High       Close  \
# 2265  30-12-2021  135.630005  135.75  6354300  136.830002  135.929993
#
#       Adjusted Close
# 2265      134.533966

# %%
ABBV_DtBfr = ABBV[ABBV['Date'] == '02-01-2018'] # were we start looking
ABBV_DtBfr.head()
# Out:
#             Date    Low       Open   Volume       High      Close  \
# 1259  02-01-2018  96.75  97.139999  4561300  98.900002  98.410004
#
#       Adjusted Close
# 1259       80.227066

# %%
ABBV_Covid = ABBV.iloc[1259:2265]
dates_ABBV= ABBV['Date'].iloc[1259:2265:60]

# %%
f = plt.figure()
f.set_figwidth(24)
f.set_figheight(10)
plt.plot(ABBV_Covid['Date'], ABBV_Covid['Close'], Color = "green")

plt.xlabel('Date')
plt.ylabel('Closing Price')
plt.title('ABBV stock Price', fontsize = 25)
plt.grid()
plt.xticks(dates_ABBV, dates_ABBV)
plt.show()
# Out:
# C:\Users\noaht\AppData\Local\Temp/ipykernel_22292/2928379195.py:4: MatplotlibDeprecationWarning: Case-insensitive properties were deprecated in 3.3 and support will be removed two minor releases later
#   plt.plot(ABBV_Covid['Date'], ABBV_Covid['Close'], Color = "green")

# %%
LLY_DtAftr = LLY[LLY['Date'] == '30-12-2021']# were We stop looking 
LLY_DtAftr.head()
# Out:
#              Date         Low        Open   Volume        High   Close  \
# 12504  30-12-2021  276.369995  279.190002  1181500  280.649994  277.25
#
#        Adjusted Close
# 12504          277.25

# %%
LLY_DtBfr = LLY[LLY['Date'] == '02-01-2018'] # were we start looking
LLY_DtBfr.head()
# Out:
#              Date        Low       Open   Volume  High  Close  Adjusted Close
# 11498  02-01-2018  84.059998  84.459999  3456700  85.0  84.68       78.010124

# %%
LLY_Covid = LLY.iloc[11498:12504]
dates_LLY= LLY['Date'].iloc[11498:12504:60]

# %%
f = plt.figure()
f.set_figwidth(24)
f.set_figheight(10)
plt.plot(LLY_Covid['Date'], LLY_Covid['Close'], Color = "green")

plt.xlabel('Date')
plt.ylabel('Closing Price')
plt.title('LLY stock Price' , fontsize = 25)
plt.grid()
plt.xticks(dates_LLY, dates_LLY)
plt.show()
# Out:
# C:\Users\noaht\AppData\Local\Temp/ipykernel_22292/3034423462.py:4: MatplotlibDeprecationWarning: Case-insensitive properties were deprecated in 3.3 and support will be removed two minor releases later
#   plt.plot(LLY_Covid['Date'], LLY_Covid['Close'], Color = "green")

# %%
MRK_DtAftr = MRK[MRK['Date'] == '30-12-2021']# were We stop looking 
MRK_DtAftr.head()
# Out:
#              Date        Low       Open   Volume       High      Close  \
# 13116  30-12-2021  76.970001  77.120003  5859100  77.610001  77.139999
#
#        Adjusted Close
# 13116       77.139999

# %%
MRK_DtBfr = MRK[MRK['Date'] == '02-01-2018'] # were we start looking
MRK_DtBfr.head()
# Out:
#              Date        Low       Open    Volume       High      Close  \
# 12110  02-01-2018  53.482822  53.998093  10556504  54.150764  53.645039
#
#        Adjusted Close
# 12110       47.371159

# %%
MRK_Covid = MRK.iloc[12110:13116]
dates_MRK= MRK['Date'].iloc[12110:13116:60]

# %%
f = plt.figure()
f.set_figwidth(24)
f.set_figheight(10)
plt.plot(MRK_Covid['Date'], MRK_Covid['Close'], Color = "green")

plt.xlabel('Date')
plt.ylabel('Closing Price')
plt.title('MRK stock Price' , fontsize = 25)
plt.grid()
plt.xticks(dates_MRK, dates_MRK)
plt.show()
# Out:
# C:\Users\noaht\AppData\Local\Temp/ipykernel_22292/1834371631.py:4: MatplotlibDeprecationWarning: Case-insensitive properties were deprecated in 3.3 and support will be removed two minor releases later
#   plt.plot(MRK_Covid['Date'], MRK_Covid['Close'], Color = "green")

# %% [markdown]
# ### SARS Data

# %%
JNJ_DtAftr = JNJ[JNJ['Date'] == '02-01-2001']# were We Start looking 
JNJ_DtAftr.head()
# Out:
#             Date       Low  Open   Volume      High  Close  Adjusted Close  \
# 7834  02-01-2001  50.78125  52.0  8855200  52.34375   51.0       29.524296
#
#       month  year
# 7834      1  2001

# %%
JNJ_DtAftr = JNJ[JNJ['Date'] == '02-01-2004']# were We stop looking 
JNJ_DtAftr.head()
# Out:
#             Date        Low   Open   Volume   High  Close  Adjusted Close  \
# 8586  02-01-2004  51.400002  51.66  6463600  52.09  51.66       31.274336
#
#       month  year
# 8586      1  2004

# %%
idxStart = 7834; 
idxStop = 8586;
JNJ_Covid = JNJ.iloc[idxStart:idxStop]
date_list = JNJ['Date'].iloc[idxStart:idxStop:60]

# %%
f = plt.figure()
f.set_figwidth(24)
f.set_figheight(10)
plt.plot(JNJ_Covid['Date'], JNJ_Covid['Close'], Color = "red")

plt.xlabel('Date')
plt.ylabel('Closing Price')
plt.title('JNJ stock Price (SARS)' , fontsize = 25)
plt.grid()
plt.xticks(date_list, date_list)
plt.show()
# Out:
# C:\Users\noaht\AppData\Local\Temp/ipykernel_22292/1405958070.py:4: MatplotlibDeprecationWarning: Case-insensitive properties were deprecated in 3.3 and support will be removed two minor releases later
#   plt.plot(JNJ_Covid['Date'], JNJ_Covid['Close'], Color = "red")

# %%
PFE_DtAftr = PFE[PFE['Date'] == '02-01-2001']# were We start looking 
PFE_DtAftr.head()
# Out:
#             Date       Low       Open    Volume       High     Close  \
# 7222  02-01-2001  43.16888  43.228176  11231108  44.354839  43.76186
#
#       Adjusted Close
# 7222       20.865398

# %%
PFE_DtAftr = PFE[PFE['Date'] == '02-01-2004']# were We stop looking 
PFE_DtAftr.head()
# Out:
#             Date        Low       Open    Volume       High      Close  \
# 7974  02-01-2004  33.538898  33.614799  17461513  34.108158  33.728653
#
#       Adjusted Close
# 7974       16.797754

# %%
idxStart = 7222; 
idxStop = 7974;
PFE_Covid = PFE.iloc[idxStart:idxStop]
dates_PFE = PFE['Date'].iloc[idxStart:idxStop:60]

f = plt.figure()
f.set_figwidth(24)
f.set_figheight(10)
plt.plot(PFE_Covid['Date'], PFE_Covid['Close'], Color = "red")

plt.xlabel('Date')
plt.ylabel('Closing Price')
plt.title('PFE stock Price' , fontsize = 25)
plt.grid()
plt.xticks(dates_PFE, dates_PFE)
plt.show()
# Out:
# C:\Users\noaht\AppData\Local\Temp/ipykernel_22292/3445723408.py:9: MatplotlibDeprecationWarning: Case-insensitive properties were deprecated in 3.3 and support will be removed two minor releases later
#   plt.plot(PFE_Covid['Date'], PFE_Covid['Close'], Color = "red")

# %%
MRK_DtAftr = MRK[MRK['Date'] == '02-01-2001']# were We start looking 
MRK_DtAftr.head()
# Out:
#             Date        Low       Open   Volume       High      Close  \
# 7834  02-01-2001  88.263359  89.098282  6332959  90.887405  88.740456
#
#       Adjusted Close
# 7834       39.876949

# %%
MRK_DtAftr = MRK[MRK['Date'] == '02-01-2004']# were We stop looking 
MRK_DtAftr.head()
# Out:
#             Date      Low      Open    Volume      High      Close  \
# 8586  02-01-2004  44.5229  46.64122  11674615  46.64122  44.895039
#
#       Adjusted Close
# 8586       22.968403

# %%
idxStart = 7834; 
idxStop = 8586;
MRK_Covid = MRK.iloc[idxStart:idxStop]
dates_MRK = MRK['Date'].iloc[idxStart:idxStop:60]

f = plt.figure()
f.set_figwidth(24)
f.set_figheight(10)
plt.plot(MRK_Covid['Date'], MRK_Covid['Close'], Color = "red")

plt.xlabel('Date')
plt.ylabel('Closing Price')
plt.title('MRK stock Price (SARS)', fontsize = 25)
plt.grid()
plt.xticks(dates_MRK, dates_MRK)
plt.show()
# Out:
# C:\Users\noaht\AppData\Local\Temp/ipykernel_22292/1871446174.py:9: MatplotlibDeprecationWarning: Case-insensitive properties were deprecated in 3.3 and support will be removed two minor releases later
#   plt.plot(MRK_Covid['Date'], MRK_Covid['Close'], Color = "red")

# %%
LLY_DtAftr = LLY[LLY['Date'] == '02-01-2001']# were We start looking 
LLY_DtAftr.head()
# Out:
#             Date   Low  Open   Volume  High  Close  Adjusted Close
# 7222  02-01-2001  90.5  93.0  4073500  95.0   91.5       47.587307

# %%
LLY_DtAftr = LLY[LLY['Date'] == '02-01-2004']# were We stop looking 
LLY_DtAftr.head()
# Out:
#             Date        Low       Open   Volume       High      Close  \
# 7974  02-01-2004  70.699997  70.849998  3780500  72.150002  71.239998
#
#       Adjusted Close
# 7974       39.129559

# %%
idxStart = 7222; 
idxStop = 7974;
LLY_Covid = LLY.iloc[idxStart:idxStop]
dates_LLY = LLY['Date'].iloc[idxStart:idxStop:60]

f = plt.figure()
f.set_figwidth(24)
f.set_figheight(10)
plt.plot(LLY_Covid['Date'], LLY_Covid['Close'], Color = "red")

plt.xlabel('Date')
plt.ylabel('Closing Price')
plt.title('LLY stock Price (SARS)', fontsize = 25)
plt.grid()
plt.xticks(dates_LLY, dates_LLY)
plt.show()
# Out:
# C:\Users\noaht\AppData\Local\Temp/ipykernel_22292/4287055399.py:9: MatplotlibDeprecationWarning: Case-insensitive properties were deprecated in 3.3 and support will be removed two minor releases later
#   plt.plot(LLY_Covid['Date'], LLY_Covid['Close'], Color = "red")

# %% [markdown]
# ### H1N1 Pandemic

# %%
JNJ_DtAftr = JNJ[JNJ['Date'] == '02-01-2008']# were We Start looking 
JNJ_DtAftr.head()
# Out:
#             Date        Low       Open    Volume  High      Close  \
# 9592  02-01-2008  65.720001  66.559998  11970500  67.0  65.910004
#
#       Adjusted Close  month  year
# 9592        43.54821      1  2008

# %%
JNJ_DtAftr = JNJ[JNJ['Date'] == '02-12-2010']# were We stop looking 
JNJ_DtAftr.head()
# Out:
#              Date    Low       Open    Volume       High      Close  \
# 10328  02-12-2010  62.27  62.389999  10160400  62.880001  62.599998
#
#        Adjusted Close  month  year
# 10328       45.532097     12  2010

# %%
idxStart = 9592; 
idxStop = 10328;
JNJ_Covid = JNJ.iloc[idxStart:idxStop]
date_list = JNJ['Date'].iloc[idxStart:idxStop:60]

# %%
f = plt.figure()
f.set_figwidth(24)
f.set_figheight(10)
plt.plot(JNJ_Covid['Date'], JNJ_Covid['Close'], Color = "blue")

plt.xlabel('Date')
plt.ylabel('Closing Price')
plt.title('JNJ stock Price (H1N1)' , fontsize = 25)
plt.grid()
plt.xticks(date_list, date_list)
plt.show()
# Out:
# C:\Users\noaht\AppData\Local\Temp/ipykernel_22292/267965830.py:4: MatplotlibDeprecationWarning: Case-insensitive properties were deprecated in 3.3 and support will be removed two minor releases later
#   plt.plot(JNJ_Covid['Date'], JNJ_Covid['Close'], Color = "blue")

# %%
PFE_DtAftr = PFE[PFE['Date'] == '02-01-2008']# were We Start looking 
PFE_DtAftr.head()
# Out:
#             Date        Low       Open    Volume       High      Close  \
# 8980  02-01-2008  21.537003  21.593927  48466820  21.850096  21.736242
#
#       Adjusted Close
# 8980       12.371157

# %%
PFE_DtAftr = PFE[PFE['Date'] == '02-12-2010']# were We stop looking 
PFE_DtAftr.head()
# Out:
#             Date        Low       Open    Volume       High      Close  \
# 9716  02-12-2010  15.768501  15.929791  35408919  15.948767  15.834915
#
#       Adjusted Close
# 9716       10.545023

# %%
idxStart = 8980; 
idxStop = 9716;
PFE_Covid = PFE.iloc[idxStart:idxStop]
date_list = PFE['Date'].iloc[idxStart:idxStop:60]

f = plt.figure()
f.set_figwidth(24)
f.set_figheight(10)
plt.plot(PFE_Covid['Date'], PFE_Covid['Close'], Color = "blue")

plt.xlabel('Date')
plt.ylabel('Closing Price')
plt.title('PFE stock Price (H1N1)', fontsize = 25)
plt.grid()
plt.xticks(date_list, date_list)
plt.show()
# Out:
# C:\Users\noaht\AppData\Local\Temp/ipykernel_22292/1705057316.py:9: MatplotlibDeprecationWarning: Case-insensitive properties were deprecated in 3.3 and support will be removed two minor releases later
#   plt.plot(PFE_Covid['Date'], PFE_Covid['Close'], Color = "blue")

# %%
MRK_DtAftr = MRK[MRK['Date'] == '02-01-2008']# were We Start looking 
MRK_DtAftr.head()
# Out:
#             Date        Low       Open    Volume       High      Close  \
# 9592  02-01-2008  54.484734  55.486641  12287276  55.830154  54.742367
#
#       Adjusted Close
# 9592       32.793255

# %%
MRK_DtAftr = MRK[MRK['Date'] == '02-12-2010']# were We stop looking 
MRK_DtAftr.head()
# Out:
#              Date       Low       Open    Volume       High      Close  \
# 10328  02-12-2010  33.40649  33.549618  39504255  33.740459  33.606869
#
#        Adjusted Close
# 10328       22.893896

# %%
idxStart = 9592; 
idxStop = 10328;
MRK_Covid = MRK.iloc[idxStart:idxStop]
date_list = MRK['Date'].iloc[idxStart:idxStop:60]

f = plt.figure()
f.set_figwidth(24)
f.set_figheight(10)
plt.plot(MRK_Covid['Date'], MRK_Covid['Close'], Color = "blue")

plt.xlabel('Date')
plt.ylabel('Closing Price')
plt.title('MRK stock Price (H1N1)' , fontsize = 25)
plt.grid()
plt.xticks(date_list, date_list)
plt.show()
# Out:
# C:\Users\noaht\AppData\Local\Temp/ipykernel_22292/1379645397.py:9: MatplotlibDeprecationWarning: Case-insensitive properties were deprecated in 3.3 and support will be removed two minor releases later
#   plt.plot(MRK_Covid['Date'], MRK_Covid['Close'], Color = "blue")

# %%
LLY_DtAftr = LLY[LLY['Date'] == '02-01-2008']# were We Start looking 
LLY_DtAftr.head()
# Out:
#             Date        Low       Open   Volume       High      Close  \
# 8980  02-01-2008  52.209999  53.459999  5556800  53.779999  52.549999
#
#       Adjusted Close
# 8980       32.212559

# %%
LLY_DtAftr = LLY[LLY['Date'] == '02-12-2010']# were We stop looking 
LLY_DtAftr.head()
# Out:
#             Date    Low       Open   Volume  High  Close  Adjusted Close
# 9716  02-12-2010  34.16  34.330002  8527100  34.5  34.25       24.466944

# %%
idxStart = 8980; 
idxStop = 9716;
LLY_Covid = LLY.iloc[idxStart:idxStop]
date_list = LLY['Date'].iloc[idxStart:idxStop:60]

f = plt.figure()
f.set_figwidth(24)
f.set_figheight(10)
plt.plot(LLY_Covid['Date'], LLY_Covid['Close'], Color = "blue")

plt.xlabel('Date')
plt.ylabel('Closing Price')
plt.title('LLY stock Price (H1N1)' , fontsize = 25 )
plt.grid()
plt.xticks(date_list, date_list)
plt.show()
# Out:
# C:\Users\noaht\AppData\Local\Temp/ipykernel_22292/282407946.py:9: MatplotlibDeprecationWarning: Case-insensitive properties were deprecated in 3.3 and support will be removed two minor releases later
#   plt.plot(LLY_Covid['Date'], LLY_Covid['Close'], Color = "blue")

# %%
JNJ_DtBfr = JNJ[JNJ['Date'] == '02-01-2018'] # were we start looking
JNJ_DtBfr.head()
# Out:
#              Date         Low        Open   Volume        High       Close  \
# 12110  02-01-2018  138.720001  139.660004  6842100  139.949997  139.229996
#
#        Adjusted Close
# 12110      125.192604

# %%
JNJ_DtBfr = JNJ[JNJ['Date'] == '05-01-2021'] # were we start looking
JNJ_DtBfr.head()
# Out:
#              Date         Low    Open   Volume        High       Close  \
# 12867  05-01-2021  155.070007  156.25  9602300  158.759995  158.339996
#
#        Adjusted Close
# 12867      154.447647

# %%
JNJ_DtBfr = JNJ[JNJ['Date'] == '01-01-2019'] # were we start looking
JNJ_DtBfr.head()
# Out:
# Empty DataFrame
# Columns: [Date, Low, Open, Volume, High, Close, Adjusted Close]
# Index: []

# %%
 cool = JNJ[12110:12867:251]
cool.head()
cool = cool['Close']
cool.head()
# Out:
# 12110    139.229996
# 12361    127.750000
# 12612    145.869995
# 12863    154.139999
# Name: Close, dtype: float64

# %%
coolpct = cool.pct_change()
coolpct
coolpct*100
# Out:
# 12110          NaN
# 12361    -8.245347
# 12612    14.183949
# 12863     5.669435
# Name: Close, dtype: float64

# %%
# Function I found that gets the index of a dataframe NOT MINE --->https://thispointer.com/python-find-indexes-of-an-element-in-pandas-dataframe/
# altered it slightly to return only the index of the row and not the column 
def getIndexes(dfObj, value):
    ''' Get index positions of value in dataframe i.e. dfObj.'''
    listOfPos = list()
    # Get bool dataframe with True at positions where the given value exists
    result = dfObj.isin([value])
    # Get list of columns that contains the value
    seriesObj = result.any()
    columnNames = list(seriesObj[seriesObj == True].index)
    # Iterate over list of columns and fetch the rows indexes where value exists
    for col in columnNames:
        rows = list(result[col][result[col] == True].index)
        for row in rows:
            listOfPos.append(row)
    # Return a list of tuples indicating the positions of value in the dataframe
    return listOfPos

# %%
JNJ_st_end = getIndexes(JNJ, '12-12-2019')
JNJ_st_end.append(getIndexes(JNJ, '25-10-2021')[0])

# %%
JNJ_dif = pd.Series([JNJ.iloc[JNJ_st_end[0]]['Close'], JNJ.iloc[JNJ_st_end[1]]['Close']])

# %%
pcntJNJ = pd.DataFrame({'JNJ' : JNJ_dif.pct_change()*100}, index = [0,1])

# %%
PFE_st_end = getIndexes(PFE, '12-12-2019')
PFE_st_end.append(getIndexes(PFE, '25-10-2021')[0])
print(PFE_st_end)

PFE_dif = pd.Series([PFE.iloc[PFE_st_end[0]]['Close'], PFE.iloc[PFE_st_end[1]]['Close']])

pcntPFE = pd.DataFrame({'PFE' : PFE_dif.pct_change()*100}, index = [0,1])
# Out:
# [11988, 12458]

# %%
ABBV_st_end = getIndexes(ABBV, '12-12-2019')
ABBV_st_end.append(getIndexes(ABBV, '25-10-2021')[0])
print(ABBV_st_end)

ABBV_dif = pd.Series([ABBV.iloc[ABBV_st_end[0]]['Close'], ABBV.iloc[ABBV_st_end[1]]['Close']])

pcntABBV = pd.DataFrame({'ABBV' : ABBV_dif.pct_change()*100}, index = [0,1])
# Out:
# [1749, 2219]

# %%
LLY_st_end = getIndexes(LLY, '12-12-2019')
LLY_st_end.append(getIndexes(LLY, '25-10-2021')[0])
print(LLY_st_end)

LLY_dif = pd.Series([LLY.iloc[LLY_st_end[0]]['Close'], LLY.iloc[LLY_st_end[1]]['Close']])

pcntLLY = pd.DataFrame({'LLY' : LLY_dif.pct_change()*100}, index = [0,1])
# Out:
# [11988, 12458]

# %%
MRK_st_end = getIndexes(MRK, '12-12-2019')
MRK_st_end.append(getIndexes(MRK, '25-10-2021')[0])

print(MRK_st_end)

MRK_dif = pd.Series([MRK.iloc[MRK_st_end[0]]['Close'], MRK.iloc[MRK_st_end[1]]['Close'],MRK.iloc[13071]['Close']])

pcntMRK = pd.DataFrame({'MRK' : MRK_dif.pct_change()*100}, index = [0,1,2])
# Out:
# [12600, 13070]

# %%
pcntMRK
# Out:
#         MRK
# 0       NaN
# 1 -4.454972
# 2  0.722503

# %%
pcntChg = pd.concat([pcntJNJ,pcntPFE, pcntMRK, pcntLLY, pcntABBV], axis = 1 )
pcntChg = pcntChg.dropna()

# %%
sns.set(rc={"figure.figsize":(20,12)})
g = sns.barplot(data = pcntChg )

# %%
# Testing 
test = pd.concat([pcntChg, (pcntChg + 20)],ignore_index = True)
test.iloc[0:1]
# Out:
#          JNJ        PFE       MRK       LLY       ABBV
# 0  16.088868  18.007532 -4.454972  101.3558  22.281073

# %%
#testing 
ax = sns.barplot(data = test.iloc[1:2],color = 'lime')
ax = sns.barplot(data = test.iloc[0:1], color = 'green', edgecolor = 'black' , lw = '5')

# %%
JNJ_st_end = getIndexes(JNJ, '02-01-2003')
JNJ_st_end.append(getIndexes(JNJ, '02-01-2004')[0])
print(JNJ_st_end)

JNJ_dif = pd.Series([JNJ.iloc[JNJ_st_end[0]]['Close'], JNJ.iloc[JNJ_st_end[1]]['Close']])
pcntJNJ = pd.DataFrame({'JNJ' : JNJ_dif.pct_change()*100}, index = [0,1])
# Out:
# [8334, 8586]

# %%
PFE_st_end = getIndexes(PFE, '02-01-2003')
PFE_st_end.append(getIndexes(PFE, '02-01-2004')[0])
print(PFE_st_end)

PFE_dif = pd.Series([PFE.iloc[PFE_st_end[0]]['Close'], PFE.iloc[PFE_st_end[1]]['Close']])
pcntPFE = pd.DataFrame({'PFE' : PFE_dif.pct_change()*100}, index = [0,1])
# Out:
# [7722, 7974]

# %%
MRK_st_end = getIndexes(MRK, '02-01-2003')
MRK_st_end.append(getIndexes(MRK, '02-01-2004')[0])
print(MRK_st_end)

MRK_dif = pd.Series([MRK.iloc[MRK_st_end[0]]['Close'], MRK.iloc[MRK_st_end[1]]['Close']])
pcntMRK = pd.DataFrame({'MRK' : MRK_dif.pct_change()*100}, index = [0,1])
# Out:
# [8334, 8586]

# %%
LLY_st_end = getIndexes(LLY, '02-01-2003')
LLY_st_end.append(getIndexes(LLY, '02-01-2004')[0])
print(LLY_st_end)

LLY_dif = pd.Series([LLY.iloc[LLY_st_end[0]]['Close'], LLY.iloc[LLY_st_end[1]]['Close']])
pcntLLY = pd.DataFrame({'LLY' : LLY_dif.pct_change()*100}, index = [0,1])
# Out:
# [7722, 7974]

# %%
temp
# Out:
#         JNJ       PFE        MRK       LLY       ABBV
# 1 -6.632933  12.74976 -19.227468  8.763356  22.281073

# %%
temp = pd.concat([pcntJNJ,pcntPFE, pcntMRK, pcntLLY, pcntABBV], axis = 1 )
temp = temp.dropna()
pcntChgF = pd.concat([pcntChg,temp], ignore_index = True)
pcntChgF.loc[1]['ABBV'] = 0
pcntChgF
# Out:
#          JNJ        PFE        MRK         LLY       ABBV
# 0  16.088868  18.007532  -4.454972  101.355800  22.281073
# 1  -6.632933  12.749760 -19.227468    8.763356   0.000000

# %%
plot = sns.barplot(data = pcntChgF.iloc[0:1],color = 'lime' ,edgecolor = 'black', lw = '7', label = 'Covid 19')
plot = sns.barplot(data = pcntChgF.iloc[1:2], color = 'Yellow', label = 'SARS' )
plt.xlabel("Company Name" , fontsize = 15)
plt.ylabel("Percent Increase", fontsize = 15 )
plt.title("Percent Growth During Pandemics", fontsize = 25)
 


plt.legend(loc = 'upper left', fontsize = 25)
